# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"/Users/sandhya/Library/Containers/com.microsoft.Excel/Data/Downloads/archive (1)/BooksDataset.csv")

# %%
df
# Out:
#                                                     Title  \
# 0                                           Goat Brothers
# 1                                      The Missing Person
# 2                       Don't Eat Your Heart Out Cookbook
# 3       When Your Corporate Umbrella Begins to Leak: A...
# 4         Amy Spangler's Breastfeeding : A Parent's Guide
# ...                                                   ...
# 103077                        Build 3 Super Serving Carts
# 103078                                  My Land of Israel
# 103079                  Tongues: To Speak or Not to Speak
# 103080   If I'm in charge here why is everybody laughing?
# 103081               Your First Puppy (Your First Series)
#
#                          Authors  \
# 0               By Colton, Larry
# 1             By Grumbach, Doris
# 2       By Piscatella, Joseph C.
# 3              By Davis, Paul D.
# 4               By Spangler, Amy
# ...                          ...
# ...

# %%
df[df['Publisher'] == 'Doubleday']
# Out:
#                                                     Title  \
# 0                                           Goat Brothers
# 39                                    Joshua and the City
# 307                The Art of Cooking with Herbs & Spices
# 322                                    Inference of guilt
# 462     A Prophet In His Own Country: The Triumphs and...
# ...                                                   ...
# 102493                        The Nobodies Album: A Novel
# 102607             Only 25 Recipies You'll Ever Need, The
# 102652                              The Futurist: A Novel
# 102739  The Company of Animals: 20 Stories of Alliance...
# 103065             Crafts of Mexico (Crafts of the world)
#
#                                               Authors  \
# 0                                    By Colton, Larry
# 39                              By Girzone, Joseph F.
# 307                             By Miloradovich, Milo
# ...

# %%
specific_Authors = ['By Colton, Larry' , 'By Othmer, James P.']
df[df['Authors'].isin(specific_Authors)]
# Out:
#                         Title              Authors  \
# 0               Goat Brothers     By Colton, Larry
# 102652  The Futurist: A Novel  By Othmer, James P.
#
#                                               Description            Category  \
# 0                                                     NaN   History , General
# 102652  Yates is a Futurist. Which is to say, he makes...   Fiction , General
#
#         Publisher             Publish Date                    Price
# 0       Doubleday  Friday, January 1, 1993  Price Starting at $8.79
# 102652  Doubleday   Thursday, June 1, 2006  Price Starting at $4.89

# %%
df[df['Authors'].str.contains('Larry')]
# Out:
#                                                     Title  \
# 0                                           Goat Brothers
# 72      Sherlock Holmes and the Red Demon by John H. W...
# 601     The World's Whales: The Complete Illustrated G...
# 717     Communications and Networking for the IBM PC a...
# 1420                        The Action Heroine's Handbook
# ...                                                   ...
# 101341                                   Programming Perl
# 101499  Ahead of the Curve: The Power of Assessment to...
# 101512            Travelers' Tales Thailand: True Stories
# 101646         Following the Law: The Total Tricks Sequel
# 102770            Musician's Guide to Home Tape Recording
#
#                                                   Authors  \
# 0                                        By Colton, Larry
# 72            By Watson, John H. and Millett, Larry (EDT)
# 601     By Balcomb, Kenneth C., Foster, Larry, and Min...
# ...

# %%
df2 = df.set_index('Authors')

# %%
df2
# Out:
#                                                                       Title  \
# Authors
# By Colton, Larry                                              Goat Brothers
# By Grumbach, Doris                                       The Missing Person
# By Piscatella, Joseph C.                  Don't Eat Your Heart Out Cookbook
# By Davis, Paul D.         When Your Corporate Umbrella Begins to Leak: A...
# By Spangler, Amy            Amy Spangler's Breastfeeding : A Parent's Guide
# ...                                                                     ...
# By Chuck Hampton                                Build 3 Super Serving Carts
# By Nover, Elizabeth Z.                                    My Land of Israel
# By Donald W. Burdick                      Tongues: To Speak or Not to Speak
# By Campbell, David P.      If I'm in charge here why is everybody laughing?
# By Carpentier, Marcel                  Your First Puppy (Your First Series)
#
# ...

# %%
df2.filter(items = ['Title' ,'Description'])
# Out:
#                                                                       Title  \
# Authors
# By Colton, Larry                                              Goat Brothers
# By Grumbach, Doris                                       The Missing Person
# By Piscatella, Joseph C.                  Don't Eat Your Heart Out Cookbook
# By Davis, Paul D.         When Your Corporate Umbrella Begins to Leak: A...
# By Spangler, Amy            Amy Spangler's Breastfeeding : A Parent's Guide
# ...                                                                     ...
# By Chuck Hampton                                Build 3 Super Serving Carts
# By Nover, Elizabeth Z.                                    My Land of Israel
# By Donald W. Burdick                      Tongues: To Speak or Not to Speak
# By Campbell, David P.      If I'm in charge here why is everybody laughing?
# By Carpentier, Marcel                  Your First Puppy (Your First Series)
#
# ...

# %%
df[df['Authors'].str.contains('Larry')].sort_values(by = 'Authors' , ascending =True)
# Out:
#                                                     Title  \
# 76913                            Jesus ; The Gift of Hope
# 1453     The Patterns of War Since the Eighteenth Century
# 101499  Ahead of the Curve: The Power of Assessment to...
# 87055   Balanced Healing: Combining Modern Medicine wi...
# 64504   Now You're Talking!: All You Need to Get Your ...
# ...                                                   ...
# 88851   Daughter of China : A True Story of Love and B...
# 87208   Daughter of China: A True Story of Love and Be...
# 32488   The 47 Best Chocolate Chip Cookies in the Worl...
# 94851   The 50 Best Cheesecakes in the World: The Winn...
# 2489    I'll Never Have Sex with You Again!: Tales fro...
#
#                                                   Authors  \
# 76913        By Abraham, Ken, Illustrated by Larry Lawson
# 1453                               By Addington, Larry H.
# 101499  By Ainsworth, Larry, Dufour, Richard, Almeida,...
# ...

# %% [raw]
# Lambda function

# %%
df.head()
# Out:
#                                                Title  \
# 0                                      Goat Brothers
# 1                                 The Missing Person
# 2                  Don't Eat Your Heart Out Cookbook
# 3  When Your Corporate Umbrella Begins to Leak: A...
# 4    Amy Spangler's Breastfeeding : A Parent's Guide
#
#                     Authors Description              Category  \
# 0          By Colton, Larry         NaN     History , General
# 1        By Grumbach, Doris         NaN     Fiction , General
# 2  By Piscatella, Joseph C.         NaN   Cooking , Reference
# 3         By Davis, Paul D.         NaN                   NaN
# 4          By Spangler, Amy         NaN                   NaN
#
#           Publisher                 Publish Date                    Price
# 0         Doubleday      Friday, January 1, 1993  Price Starting at $8.79
# 1  Putnam Pub Group        Sunday, March 1, 1981  Price Starting at $4.99
# ...

# %%
df['Publish Date'].unique()
# Out:
# array(['Friday, January 1, 1993', 'Sunday, March 1, 1981',
#        'Thursday, September 1, 1983', 'Monday, April 1, 1991',
#        'Saturday, February 1, 1997', 'Wednesday, January 1, 1997',
#        'Saturday, May 1, 1993', 'Saturday, September 1, 2001',
#        'Monday, June 1, 1987', 'Sunday, June 1, 1986',
#        'Sunday, January 1, 1978', 'Monday, October 1, 2001',
#        'Sunday, September 1, 1996', 'Friday, May 1, 1998',
#        'Tuesday, September 1, 1998', 'Monday, January 1, 1979',
#        'Thursday, January 1, 1998', 'Tuesday, January 1, 1991',
#        'Monday, October 1, 1990', 'Wednesday, April 1, 1992',
#        'Friday, February 1, 1991', 'Saturday, January 1, 1994',
#        'Tuesday, May 1, 1979', 'Friday, October 1, 1993',
#        'Tuesday, August 1, 1961', 'Saturday, May 1, 1999',
#        'Saturday, October 1, 1994', 'Sunday, January 1, 1995',
#        'Saturday, March 1, 1997', 'Saturday, November 1, 2003',
# ...

# %%
def book_type(yr):
    if yr > 'Friday, December 1, 1995' :
        return 'new'
    else:
        return 'old'

# %%
df['book type'] = df['Publish Date'].apply(lambda x : book_type(x))

# %%
df
# Out:
#                                                     Title  \
# 0                                           Goat Brothers
# 1                                      The Missing Person
# 2                       Don't Eat Your Heart Out Cookbook
# 3       When Your Corporate Umbrella Begins to Leak: A...
# 4         Amy Spangler's Breastfeeding : A Parent's Guide
# ...                                                   ...
# 103077                        Build 3 Super Serving Carts
# 103078                                  My Land of Israel
# 103079                  Tongues: To Speak or Not to Speak
# 103080   If I'm in charge here why is everybody laughing?
# 103081               Your First Puppy (Your First Series)
#
#                          Authors  \
# 0               By Colton, Larry
# 1             By Grumbach, Doris
# 2       By Piscatella, Joseph C.
# 3              By Davis, Paul D.
# 4               By Spangler, Amy
# ...                          ...
# ...

# %% [raw]
# Pandas Visualisation

# %%
df.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 df.plot()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/plotting/_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:451, in MPLPlot.generate(self)
#     449 def generate(self) -> None:
# ...

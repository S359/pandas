# %%
import numpy as np
import matplotlib.pyplot as pl

# %%
x = np.linspace(1,5,6)

# %%
y = np.log(x)

# %%
pl.plot(x,y)

# %%
x = [2003,2006,2009,2010,2012]
y = [40,50,60,70,80]
pl.xlabel("year")
pl.ylabel("price of the petrol")
pl.figure(figsize=(15,8))
pl.plot(x,y,'ro',linestyle="dashed")
pl.scatter(x,y)
pl.show()
